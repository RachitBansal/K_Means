# %% [markdown]
# #### Because normal K_Means can get stuck in a local minima and is highly dependent on the initial centre initialistaion

# %%
import numpy as np 
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from sklearn.datasets import make_blobs

# %%
x,y = make_blobs(n_samples=500,centers=5,random_state=3)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=5)

# %%
kmeans.fit(x,y)
centers = kmeans.cluster_centers_
print(centers)
# Out:
# [[-3.97953526  0.19458336]
#  [ 7.8649674   7.97988109]
#  [-7.6726196  -5.69211059]
#  [-9.0671623  -0.96740759]
#  [ 0.88641907  4.19441853]]

# %%
pred = kmeans.labels_
print(pred)
# Out:
# [2 1 0 2 2 0 3 2 1 2 1 0 1 2 0 2 1 2 2 1 4 4 2 0 2 4 3 3 0 3 2 3 4 4 2 4 1
#  1 2 4 4 4 3 3 0 1 1 3 3 3 1 2 3 2 2 4 2 2 1 0 1 0 0 2 3 1 0 0 4 0 4 2 4 2
#  4 0 2 3 4 4 0 4 0 3 1 3 0 1 3 0 3 4 2 4 4 1 2 0 0 4 1 4 0 0 1 1 1 0 0 2 1
#  3 2 1 0 4 1 3 4 0 1 0 3 2 4 3 3 3 2 2 0 0 2 1 1 3 0 3 0 2 2 4 0 1 3 2 1 1
#  2 0 2 2 0 0 1 4 4 3 0 2 4 1 3 4 1 4 1 4 4 4 3 2 4 1 4 3 2 0 1 3 1 2 1 4 3
#  3 4 2 0 1 4 0 3 2 3 4 0 3 2 2 2 4 4 1 2 3 3 2 1 2 2 2 4 1 0 1 2 2 1 3 0 3
#  3 4 2 0 2 0 3 4 0 0 2 4 2 4 0 1 0 4 4 1 2 2 0 0 4 1 4 2 3 1 3 2 3 3 3 3 1
#  4 1 2 4 1 3 0 1 1 1 3 2 2 0 4 4 1 0 0 2 0 3 0 1 1 3 3 4 3 3 1 4 2 0 4 0 3
#  0 0 1 2 4 1 4 4 2 3 4 0 4 3 2 2 0 1 4 3 1 4 0 3 1 3 2 4 3 0 0 4 4 4 2 3 4
#  2 1 0 0 3 1 1 0 0 3 4 4 4 2 3 1 3 2 4 1 1 0 4 4 3 4 3 0 0 0 3 4 2 4 0 3 3
#  1 2 1 3 2 3 0 1 4 1 0 2 2 1 1 4 1 4 3 0 1 3 2 2 1 0 4 3 2 2 2 3 1 4 1 1 1
#  3 4 0 1 0 0 3 0 2 0 2 1 4 4 2 1 3 2 4 0 1 3 0 3 3 1 3 0 3 1 3 0 3 2 4 4 3
#  4 1 4 4 3 2 2 0 3 4 0 3 0 1 0 1 2 4 0 2 0 2 2 4 2 4 3 1 1 0 2 2 3 3 1 3 3
#  1 3 1 1 1 3 4 3 0 1 0 0 3 0 3 4 4 3 1]

# %%
plt.scatter(x[:,0],x[:,1],c=pred)
plt.scatter(centers[:,0],centers[:,1],c='red')
plt.show()
